# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.mubasher.info/stocks"

try:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    quotes = []
    rows = soup.find_all('tr', {'class': 'quote-row'})
    
    for row in rows[:10]:
        tds = row.find_all('td')
        if len(tds) >= 4: 
            quotes.append({
                'Symbol': tds[0].text.strip(),
                'Price': tds[1].text.strip(),
                'Change': tds[2].text.strip(),
                'Volume': tds[3].text.strip()
            })
    
    if quotes:
        quotes_df = pd.DataFrame(quotes)
        print("Mubasher Live Quotes:")
        print(quotes_df)
    else:
        print("no data ")
        
except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# No quotes found - Mubasher likely requires JavaScript rendering
